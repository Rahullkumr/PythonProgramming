# %%
import pandas as pd

# %%
# data=pd.read_csv(r"student.csv")

# print(data)


# in cmd ====> pip install pandas openpyxl
import openpyxl
data1=pd.read_excel(r"student.xlsx")

print(data1)
# Out:
#               timestamp  roll_num         name    middlename     surname  \
# 0   30/05/2023 14:26:35   2201184      Shubham        Kumar        Sinha
# 1   30/05/2023 14:26:56   2201129       Pranav      Prashant      Modale
# 2   30/05/2023 14:27:27   2201125      Pratik        Sharad     Masalkar
# 3   30/05/2023 14:27:43   2201154       Ranvir       Gajanan       Pawar
# 4   30/05/2023 14:27:48   2201193    Siddhesh         Suresh     Uttekar
# 5   30/05/2023 14:28:03   2201115       Sairaj       Shirish    Lumpatki
# 6   30/05/2023 14:28:03   2201110       Rahul          Kumar       Kumar
# 7   30/05/2023 14:28:06   2201124       Akash      Sambhaji      Markile
# 8   30/05/2023 14:28:07   2201145       harsh        subhash     patidar
# 9   30/05/2023 14:28:08   2201105        Omkar        Milind    Kulkarni
# 10  30/05/2023 14:28:10   2201171      Prajwal        Pramod     Shendge
# 11  30/05/2023 14:28:10   2201121       tejas    Uttareshwar        mane
# ...
